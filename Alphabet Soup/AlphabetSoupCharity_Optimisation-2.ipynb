# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS'], inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT   ASK_AMT  IS_SUCCESSFUL
# 0       Association       1              0      5000              1
# 1      Co-operative       1         1-9999    108590              1
# 2       Association       1              0      5000              0
# 3             Trust       1    10000-24999      6692              1
# 4             Trust       1  100000-499999    142590              1
# ...             ...     ...            ...       ...            ...
# 34294   Association       1              0      5000              0
# 34295   Association       1              0      5000              0
# 34296   Association       1              0      5000              0
# 34297   Association       1              0      5000              1
# 34298  Co-operative       1          1M-5M  36500179              0
#
# [34299 rows x 9 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Choose a cutoff value (less than 500 occurrences)
cutoff_value = 100

# Create a list of application types to replace
application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_type_counts = application_df['CLASSIFICATION'].value_counts()
classification_type_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_type_counts_more_than_1 = classification_type_counts [classification_type_counts >1]
classification_type_counts_more_than_1
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 100

# Create a list of application types to replace
classifications_to_replace = classification_type_counts[classification_type_counts < cutoff_value].index.tolist()
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# Identify categorical columns
application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()

# Convert categorical columns to one-hot encoded columns
application_df_encoded = pd.get_dummies(application_df, columns=application_cat)

# %%
# Split our preprocessed data into our features and target arrays
# Define the target column
target_column = 'IS_SUCCESSFUL'

# Split the dataframe into features and target
X = application_df_encoded.drop(columns=[target_column])  # Features
y = application_df_encoded[target_column]  # Target

# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer
nn = tf.keras.models.Sequential()

number_input_features = len(X_train.columns)
hidden_nodes_layer1 = 60
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 15
hidden_nodes_layer4 = 5

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)
nn.add(tf.keras.layers.Dropout(0.2))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))
nn.add(tf.keras.layers.Dropout(0.2))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))
nn.add(tf.keras.layers.Dropout(0.2))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="tanh"))
nn.add(tf.keras.layers.Dropout(0.2))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# C:\Users\Muz\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 60)                  │           2,940 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 30)                  │           1,830 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 15)                  │             465 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 15)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 5)                   │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 5)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,321 (20.79 KB)
#  Trainable params: 5,321 (20.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

optimizer = Adam(learning_rate=0.0001)
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
# Create a callback that saves the model's weights every five epochs

# Define the checkpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath='../Weights per 5 epochs nnm3/model_weights_epoch_{epoch:02d}.weights.h5',  # Filepath to save weights
    save_weights_only=True,  # Save only the weights
    save_freq=5 * (len(X_train_scaled) // 64)  # Save every 5 epochs
)

# Define early stopping callback to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Train the model with the checkpoint callback and early stopping
fit_model = nn.fit(
    X_train_scaled, y_train,
    epochs=150,  
    batch_size=64,
    validation_split=0.20,
    callbacks=[checkpoint_callback, early_stopping]
)
# Out:
# Epoch 1/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4944 - loss: 0.7698 - val_accuracy: 0.6879 - val_loss: 0.6131
# Epoch 2/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6265 - loss: 0.6570 - val_accuracy: 0.7252 - val_loss: 0.5778
# Epoch 3/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6632 - loss: 0.6311 - val_accuracy: 0.7267 - val_loss: 0.5681
# Epoch 4/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6745 - loss: 0.6211 - val_accuracy: 0.7285 - val_loss: 0.5626
# Epoch 5/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6742 - loss: 0.6235 - val_accuracy: 0.7304 - val_loss: 0.5601
# Epoch 6/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6901 - loss: 0.6074 - val_accuracy: 0.7341 - val_loss: 0.5577
# Epoch 7/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6925 - loss: 0.6056 - val_accuracy: 0.7347 - val_loss: 0.5562
# Epoch 8/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6912 - loss: 0.6059 - val_accuracy: 0.7349 - val_loss: 0.5552
# Epoch 9/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6940 - loss: 0.6027 - val_accuracy: 0.7343 - val_loss: 0.5541
# Epoch 10/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7012 - loss: 0.5934 - val_accuracy: 0.7343 - val_loss: 0.5533
# Epoch 11/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7007 - loss: 0.5941 - val_accuracy: 0.7343 - val_loss: 0.5528
# Epoch 12/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7063 - loss: 0.5946 - val_accuracy: 0.7355 - val_loss: 0.5523
# Epoch 13/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7002 - loss: 0.5950 - val_accuracy: 0.7353 - val_loss: 0.5519
# Epoch 14/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7082 - loss: 0.5870 - val_accuracy: 0.7349 - val_loss: 0.5520
# Epoch 15/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7118 - loss: 0.5847 - val_accuracy: 0.7374 - val_loss: 0.5514
# Epoch 16/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7073 - loss: 0.5871 - val_accuracy: 0.7378 - val_loss: 0.5510
# Epoch 17/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7082 - loss: 0.5860 - val_accuracy: 0.7388 - val_loss: 0.5508
# Epoch 18/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7080 - loss: 0.5857 - val_accuracy: 0.7386 - val_loss: 0.5506
# Epoch 19/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7185 - loss: 0.5815 - val_accuracy: 0.7386 - val_loss: 0.5504
# Epoch 20/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7096 - loss: 0.5827 - val_accuracy: 0.7384 - val_loss: 0.5505
# Epoch 21/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7154 - loss: 0.5835 - val_accuracy: 0.7386 - val_loss: 0.5504
# Epoch 22/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7141 - loss: 0.5814 - val_accuracy: 0.7386 - val_loss: 0.5505
# Epoch 23/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7171 - loss: 0.5801 - val_accuracy: 0.7386 - val_loss: 0.5503
# Epoch 24/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7166 - loss: 0.5765 - val_accuracy: 0.7384 - val_loss: 0.5498
# Epoch 25/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7132 - loss: 0.5834 - val_accuracy: 0.7386 - val_loss: 0.5499
# Epoch 26/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7173 - loss: 0.5746 - val_accuracy: 0.7384 - val_loss: 0.5500
# Epoch 27/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7118 - loss: 0.5791 - val_accuracy: 0.7378 - val_loss: 0.5500
# Epoch 28/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7174 - loss: 0.5805 - val_accuracy: 0.7380 - val_loss: 0.5499
# Epoch 29/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7211 - loss: 0.5731 - val_accuracy: 0.7376 - val_loss: 0.5495
# Epoch 30/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7183 - loss: 0.5774 - val_accuracy: 0.7376 - val_loss: 0.5497
# Epoch 31/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7209 - loss: 0.5726 - val_accuracy: 0.7376 - val_loss: 0.5497
# Epoch 32/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7204 - loss: 0.5760 - val_accuracy: 0.7372 - val_loss: 0.5494
# Epoch 33/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7149 - loss: 0.5779 - val_accuracy: 0.7370 - val_loss: 0.5496
# Epoch 34/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7226 - loss: 0.5715 - val_accuracy: 0.7372 - val_loss: 0.5499
# Epoch 35/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7179 - loss: 0.5772 - val_accuracy: 0.7374 - val_loss: 0.5498
# Epoch 36/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7233 - loss: 0.5702 - val_accuracy: 0.7372 - val_loss: 0.5495
# Epoch 37/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7254 - loss: 0.5711 - val_accuracy: 0.7370 - val_loss: 0.5495
# Epoch 38/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7161 - loss: 0.5780 - val_accuracy: 0.7370 - val_loss: 0.5491
# Epoch 39/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7167 - loss: 0.5776 - val_accuracy: 0.7370 - val_loss: 0.5491
# Epoch 40/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7206 - loss: 0.5731 - val_accuracy: 0.7376 - val_loss: 0.5494
# Epoch 41/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7249 - loss: 0.5706 - val_accuracy: 0.7374 - val_loss: 0.5494
# Epoch 42/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7231 - loss: 0.5685 - val_accuracy: 0.7368 - val_loss: 0.5495
# Epoch 43/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7158 - loss: 0.5779 - val_accuracy: 0.7376 - val_loss: 0.5494
# Epoch 44/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7203 - loss: 0.5720 - val_accuracy: 0.7376 - val_loss: 0.5494
# Epoch 45/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7252 - loss: 0.5692 - val_accuracy: 0.7366 - val_loss: 0.5493
# Epoch 46/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7196 - loss: 0.5758 - val_accuracy: 0.7366 - val_loss: 0.5492
# Epoch 47/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7203 - loss: 0.5726 - val_accuracy: 0.7366 - val_loss: 0.5490
# Epoch 48/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7237 - loss: 0.5691 - val_accuracy: 0.7364 - val_loss: 0.5491
# Epoch 49/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7173 - loss: 0.5767 - val_accuracy: 0.7368 - val_loss: 0.5491
# Epoch 50/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7258 - loss: 0.5697 - val_accuracy: 0.7374 - val_loss: 0.5493
# Epoch 51/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7183 - loss: 0.5756 - val_accuracy: 0.7366 - val_loss: 0.5490
# Epoch 52/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7234 - loss: 0.5701 - val_accuracy: 0.7368 - val_loss: 0.5489
# Epoch 53/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7256 - loss: 0.5669 - val_accuracy: 0.7366 - val_loss: 0.5486
# Epoch 54/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7258 - loss: 0.5646 - val_accuracy: 0.7366 - val_loss: 0.5484
# Epoch 55/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7309 - loss: 0.5658 - val_accuracy: 0.7366 - val_loss: 0.5486
# Epoch 56/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7222 - loss: 0.5709 - val_accuracy: 0.7368 - val_loss: 0.5484
# Epoch 57/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7212 - loss: 0.5687 - val_accuracy: 0.7364 - val_loss: 0.5486
# Epoch 58/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7210 - loss: 0.5701 - val_accuracy: 0.7366 - val_loss: 0.5486
# Epoch 59/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7192 - loss: 0.5723 - val_accuracy: 0.7366 - val_loss: 0.5489
# Epoch 60/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7210 - loss: 0.5685 - val_accuracy: 0.7368 - val_loss: 0.5486
# Epoch 61/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7268 - loss: 0.5670 - val_accuracy: 0.7366 - val_loss: 0.5486
# Epoch 62/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7183 - loss: 0.5727 - val_accuracy: 0.7368 - val_loss: 0.5487
# Epoch 63/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7308 - loss: 0.5644 - val_accuracy: 0.7368 - val_loss: 0.5485
# Epoch 64/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7295 - loss: 0.5638 - val_accuracy: 0.7372 - val_loss: 0.5482
# Epoch 65/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7276 - loss: 0.5661 - val_accuracy: 0.7368 - val_loss: 0.5483
# Epoch 66/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7230 - loss: 0.5681 - val_accuracy: 0.7372 - val_loss: 0.5485
# Epoch 67/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7237 - loss: 0.5664 - val_accuracy: 0.7374 - val_loss: 0.5483
# Epoch 68/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7306 - loss: 0.5671 - val_accuracy: 0.7370 - val_loss: 0.5483
# Epoch 69/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7263 - loss: 0.5648 - val_accuracy: 0.7372 - val_loss: 0.5483
# Epoch 70/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7233 - loss: 0.5695 - val_accuracy: 0.7364 - val_loss: 0.5483
# Epoch 71/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7215 - loss: 0.5621 - val_accuracy: 0.7364 - val_loss: 0.5481
# Epoch 72/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7232 - loss: 0.5711 - val_accuracy: 0.7370 - val_loss: 0.5479
# Epoch 73/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7313 - loss: 0.5613 - val_accuracy: 0.7372 - val_loss: 0.5480
# Epoch 74/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7246 - loss: 0.5663 - val_accuracy: 0.7372 - val_loss: 0.5479
# Epoch 75/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7269 - loss: 0.5627 - val_accuracy: 0.7370 - val_loss: 0.5475
# Epoch 76/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7292 - loss: 0.5672 - val_accuracy: 0.7372 - val_loss: 0.5476
# Epoch 77/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7243 - loss: 0.5677 - val_accuracy: 0.7378 - val_loss: 0.5475
# Epoch 78/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7236 - loss: 0.5642 - val_accuracy: 0.7374 - val_loss: 0.5474
# Epoch 79/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7184 - loss: 0.5735 - val_accuracy: 0.7376 - val_loss: 0.5476
# Epoch 80/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7219 - loss: 0.5662 - val_accuracy: 0.7380 - val_loss: 0.5477
# Epoch 81/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7269 - loss: 0.5643 - val_accuracy: 0.7366 - val_loss: 0.5478
# Epoch 82/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7226 - loss: 0.5643 - val_accuracy: 0.7372 - val_loss: 0.5475
# Epoch 83/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7314 - loss: 0.5586 - val_accuracy: 0.7362 - val_loss: 0.5478
# Epoch 84/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7282 - loss: 0.5635 - val_accuracy: 0.7372 - val_loss: 0.5475
# Epoch 85/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7264 - loss: 0.5646 - val_accuracy: 0.7374 - val_loss: 0.5476
# Epoch 86/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7283 - loss: 0.5581 - val_accuracy: 0.7376 - val_loss: 0.5473
# Epoch 87/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7247 - loss: 0.5634 - val_accuracy: 0.7370 - val_loss: 0.5474
# Epoch 88/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7329 - loss: 0.5598 - val_accuracy: 0.7368 - val_loss: 0.5475
# Epoch 89/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7349 - loss: 0.5611 - val_accuracy: 0.7361 - val_loss: 0.5474
# Epoch 90/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7250 - loss: 0.5682 - val_accuracy: 0.7372 - val_loss: 0.5473
# Epoch 91/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7223 - loss: 0.5691 - val_accuracy: 0.7374 - val_loss: 0.5474
# Epoch 92/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7215 - loss: 0.5687 - val_accuracy: 0.7370 - val_loss: 0.5475
# Epoch 93/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7255 - loss: 0.5599 - val_accuracy: 0.7362 - val_loss: 0.5471
# Epoch 94/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7243 - loss: 0.5658 - val_accuracy: 0.7361 - val_loss: 0.5472
# Epoch 95/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7280 - loss: 0.5609 - val_accuracy: 0.7364 - val_loss: 0.5471
# Epoch 96/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7327 - loss: 0.5592 - val_accuracy: 0.7362 - val_loss: 0.5474
# Epoch 97/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7279 - loss: 0.5630 - val_accuracy: 0.7366 - val_loss: 0.5474
# Epoch 98/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7274 - loss: 0.5653 - val_accuracy: 0.7370 - val_loss: 0.5472
# Epoch 99/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7279 - loss: 0.5644 - val_accuracy: 0.7359 - val_loss: 0.5473
# Epoch 100/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7321 - loss: 0.5580 - val_accuracy: 0.7362 - val_loss: 0.5473
# Epoch 101/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7238 - loss: 0.5690 - val_accuracy: 0.7364 - val_loss: 0.5471
# Epoch 102/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7245 - loss: 0.5633 - val_accuracy: 0.7366 - val_loss: 0.5468
# Epoch 103/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7328 - loss: 0.5578 - val_accuracy: 0.7372 - val_loss: 0.5471
# Epoch 104/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7228 - loss: 0.5680 - val_accuracy: 0.7364 - val_loss: 0.5471
# Epoch 105/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7251 - loss: 0.5669 - val_accuracy: 0.7362 - val_loss: 0.5472
# Epoch 106/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7259 - loss: 0.5639 - val_accuracy: 0.7366 - val_loss: 0.5470
# Epoch 107/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7281 - loss: 0.5613 - val_accuracy: 0.7366 - val_loss: 0.5471
# Epoch 108/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7258 - loss: 0.5621 - val_accuracy: 0.7361 - val_loss: 0.5469
# Epoch 109/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7267 - loss: 0.5641 - val_accuracy: 0.7357 - val_loss: 0.5471
# Epoch 110/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7232 - loss: 0.5678 - val_accuracy: 0.7364 - val_loss: 0.5470
# Epoch 111/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7286 - loss: 0.5595 - val_accuracy: 0.7357 - val_loss: 0.5469
# Epoch 112/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7292 - loss: 0.5590 - val_accuracy: 0.7355 - val_loss: 0.5467
# Epoch 113/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7256 - loss: 0.5623 - val_accuracy: 0.7355 - val_loss: 0.5469
# Epoch 114/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7285 - loss: 0.5602 - val_accuracy: 0.7362 - val_loss: 0.5466
# Epoch 115/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7343 - loss: 0.5582 - val_accuracy: 0.7364 - val_loss: 0.5468
# Epoch 116/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7324 - loss: 0.5567 - val_accuracy: 0.7357 - val_loss: 0.5469
# Epoch 117/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7276 - loss: 0.5633 - val_accuracy: 0.7362 - val_loss: 0.5468
# Epoch 118/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7249 - loss: 0.5667 - val_accuracy: 0.7361 - val_loss: 0.5468
# Epoch 119/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7310 - loss: 0.5579 - val_accuracy: 0.7364 - val_loss: 0.5468
# Epoch 120/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7266 - loss: 0.5620 - val_accuracy: 0.7362 - val_loss: 0.5468
# Epoch 121/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7270 - loss: 0.5621 - val_accuracy: 0.7357 - val_loss: 0.5469
# Epoch 122/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7318 - loss: 0.5625 - val_accuracy: 0.7361 - val_loss: 0.5469
# Epoch 123/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7260 - loss: 0.5623 - val_accuracy: 0.7357 - val_loss: 0.5470
# Epoch 124/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7312 - loss: 0.5595 - val_accuracy: 0.7362 - val_loss: 0.5469

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - 965us/step - accuracy: 0.7304 - loss: 0.5524
# Loss: 0.5524091720581055, Accuracy: 0.7303789854049683

# %%
# Export our model to HDF5 file
nn.save('HDF5/AlphabetSoupCharity_Optimisation2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
